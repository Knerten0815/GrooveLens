# %%
import pandas as pd

# %%
data = pd.read_csv('musicnn_classification.csv', encoding="latin-1")
data.head()
# Out:
#    Unnamed: 0   drummer                session                        id  \
# 0           0  drummer1  drummer1/eval_session   drummer1/eval_session/1
# 1           1  drummer1  drummer1/eval_session  drummer1/eval_session/10
# 2           2  drummer1  drummer1/eval_session   drummer1/eval_session/2
# 3           3  drummer1  drummer1/eval_session   drummer1/eval_session/3
# 4           4  drummer1  drummer1/eval_session   drummer1/eval_session/4
#
#            style simplified_style  bpm  beat_type time_signature  \
# 0   funk/groove1             funk  138          1            4-4
# 1  soul/groove10             funk  102          1            4-4
# 2   funk/groove2             funk  105          1            4-4
# 3   soul/groove3             funk   86          1            4-4
# 4   soul/groove4             funk   80          1            4-4
#
#                                        midi_filename  ...   rms_std  \
# ...

# %%
data['fitting_tags'].notnull().sum() / len(data)
# Out:
# 0.7253521126760564

# %%
data['fitting_tags'].value_counts()
# Out:
# fitting_tags
# ['rock', 'rock']             159
# ['jazz']                      45
# ['funk']                      41
# ['soul']                      21
# ['pop']                        9
# ['rock']                       8
# ['beat']                       6
# ['pop', 'pop']                 4
# ['fast', 'jazz']               3
# ['jazz', 'funk']               2
# ['dance']                      2
# ['soft', 'pop']                2
# ['rock', 'indie', 'rock']      2
# ['slow']                       1
# ['punk']                       1
# ['rock', 'rock', 'folk']       1
# ['fast', 'funk']               1
# ['blues']                      1
# Name: count, dtype: int64

# %%
data[data.simplified_style == 'latin'][['fitting_tags', 'style']].value_counts()
# Out:
# fitting_tags  style
# ['beat']      afrobeat       4
# ['funk']      funk/latin     2
# ['slow']      reggae/slow    1
# Name: count, dtype: int64

# %%
data[data.fitting_tags == '[\'beat\']'][['fitting_tags', 'style', 'simplified_style']]
# Out:
#     fitting_tags            style simplified_style
# 40      ['beat']  dance/breakbeat           hiphop
# 41      ['beat']  dance/breakbeat           hiphop
# 69      ['beat']         afrobeat            latin
# 375     ['beat']         afrobeat            latin
# 376     ['beat']         afrobeat            latin
# 386     ['beat']         afrobeat            latin
