# %%
import os
import pandas as pd
from musicnn.tagger import top_tags

SAMPLE_DURATION = 3.0

# %%
data = pd.read_csv('data_reduced.csv', encoding="latin-1")
data.head()

# only use beats longer than SAMPLE_DURATION, not fills
beat_mask = (data['beat_type'] == 1) & (data.duration >= SAMPLE_DURATION)
data = data[beat_mask]

# %%
data[data.simplified_style == 'rock'].audio_filename
# Out:
# 8       drummer1/eval_session/8_rock-groove8_65_beat_4...
# 125     drummer1/session1/202_rock-halftime_140_beat_4...
# 225     drummer1/session1/51_rock-shuffle_125_beat_4-4...
# 291      drummer1/session2/110_rock-prog_190_beat_4-4.wav
# 292      drummer1/session2/111_rock-prog_110_beat_5-4.wav
#                               ...
# 1085            drummer9/session1/5_rock_100_beat_4-4.wav
# 1086            drummer9/session1/6_rock_100_beat_4-4.wav
# 1087            drummer9/session1/7_rock_100_beat_4-4.wav
# 1088            drummer9/session1/8_rock_100_beat_4-4.wav
# 1089            drummer9/session1/9_rock_100_beat_4-4.wav
# Name: audio_filename, Length: 179, dtype: object

# %%
audio_path = os.path.join('..', 'Datasets', 'groove')
filepath = os.path.join(audio_path, 'drummer1/eval_session/1_funk-groove1_138_beat_4-4.wav')

tags = []

tags += top_tags(filepath, model='MTT_musicnn', topN=10, print_tags=False)
tags += top_tags(filepath, model='MSD_musicnn', topN=10, print_tags=False)
tags
# Out:
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ['drums',
#  'guitar',
#  'beat',
#  'fast',
#  'rock',
#  'beats',
#  'slow',
#  'no vocals',
#  'no vocal',
#  'no voice',
#  'indian',
#  'strings',
#  'quiet',
#  'solo',
#  'piano',
#  'jazz',
#  'electronic',
#  'experimental',
#  'indie',
#  'alternative',
#  'rock',
#  'electronica',
#  'instrumental',
#  'chillout',
#  'female vocalists',
#  'ambient',
#  'indie rock',
#  'chill',
#  'funk',
#  'electro']

# %%
def classify_genre(audio_filename, style, topN=10):
    filepath = os.path.join(audio_path, audio_filename)
    print(filepath)
    tags = top_tags(filepath, model='MTT_musicnn', topN=topN, print_tags=False)
    tags += top_tags(filepath, model='MSD_musicnn', topN=topN, print_tags=False)
    
    #check if any of the tags are in the style string and add it to the fitting_tags_list
    fitting_tags_list = []
    for tag in tags:
        if tag in style:
            fitting_tags_list.append(tag)
    
    if len(fitting_tags_list) > 0:
        return fitting_tags_list

# %%
data['fitting_tags'] = data.apply(lambda x: classify_genre(x.audio_filename, x.style, topN=10), axis=1)
# Out:
# ..\Datasets\groove\drummer1/eval_session/1_funk-groove1_138_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/eval_session/10_soul-groove10_102_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/eval_session/2_funk-groove2_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/eval_session/3_soul-groove3_86_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/eval_session/4_soul-groove4_80_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/eval_session/5_funk-groove5_84_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/eval_session/6_hiphop-groove6_87_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/eval_session/7_pop-groove7_138_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/eval_session/8_rock-groove8_65_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/eval_session/9_soul-groove9_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/1_funk_80_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/100_neworleans-secondline_94_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/101_dance-disco_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/102_funk_95_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/126_funk-fast_125_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/145_latin-brazilian-baiao_95_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/146_latin-brazilian-baiao_95_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/176_afrocuban_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/183_afrocuban_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/184_reggae_78_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/2_funk_80_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/201_reggae-slow_64_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/202_rock-halftime_140_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/239_funk-purdieshuffle_130_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/28_latin-samba_116_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/3_funk_80_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/38_latin-samba_116_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/4_jazz-funk_116_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/47_jazz_102_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/48_jazz_93_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/49_jazz_125_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/5_jazz-funk_116_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/50_jazz_125_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/51_rock-shuffle_125_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/52_jazz_125_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/75_jazz_125_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/76_jazz-mediumfast_180_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/77_jazz-mediumfast_180_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/78_jazz-fast_290_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/79_latin-reggaeton_90_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/80_dance-breakbeat_170_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/81_dance-breakbeat_170_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session1/82_neworleans-funk_84_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/1_latin-chacarera_157_beat_3-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/10_country_114_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/110_rock-prog_190_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/111_rock-prog_110_beat_5-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/112_afrocuban-bembe_122_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/142_gospel_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/161_afrocuban-rhumba_110_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/180_rock_50_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/181_rock_115_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/2_latin-chacarera_118_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/3_latin-chacarera_118_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/32_punk_140_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/33_punk_128_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/34_punk_128_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/35_punk_128_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/36_punk_128_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/4_jazz_120_beat_3-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/5_jazz_200_beat_3-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/6_rock_102_beat_3-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/62_punk_144_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/7_jazz-march_88_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/8_jazz-march_176_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/9_jazz-march_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session2/90_funk-rock_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session3/1_rock-prog_125_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session3/10_rock-folk_90_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session3/11_afrobeat_94_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session3/12_latin-bomba_96_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session3/13_rock_115_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session3/14_rock_94_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session3/15_funk_117_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session3/16_funk_117_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session3/17_afrocuban-calypso_108_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session3/18_rock_128_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session3/2_jazz-swing_185_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session3/3_rock-rockabilly_200_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session3/4_jazz-linear_182_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session3/5_jazz-linear_128_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session3/6_dance-disco_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session3/7_dance-disco_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session3/8_rock_135_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer1/session3/9_rock_135_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer10/session1/1_jazz-swing_124_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer10/session1/10_jazz-swing_110_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer10/session1/2_jazz-swing_215_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer10/session1/3_jazz-swing_215_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer10/session1/4_jazz-swing_215_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer10/session1/5_jazz-swing_215_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer10/session1/6_jazz-swing_215_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer10/session1/7_jazz-swing_215_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer10/session1/8_jazz-swing_215_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer10/session1/9_jazz-swing_110_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/1_rock_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/10_rock_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/11_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/12_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/13_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/14_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/15_jazz_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/16_jazz_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/17_jazz_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/18_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/19_jazz_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/2_rock_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/20_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/21_jazz_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/22_jazz_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/23_jazz_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/24_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/25_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/29_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/3_rock_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/31_jazz_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/32_jazz_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/33_jazz_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/35_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/39_jazz_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/4_rock_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/44_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/45_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/48_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/49_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/5_rock_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/50_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/6_rock_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/7_rock_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/8_jazz_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session1/9_rock_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/1_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/10_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/11_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/12_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/13_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/14_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/15_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/16_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/17_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/18_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/2_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/20_rock_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/21_rock_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/22_rock_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/23_rock_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/24_rock_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/25_hiphop_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/26_hiphop_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/27_jazz_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/28_rock_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/29_rock_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/3_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/30_rock_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/31_hiphop_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/32_hiphop_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/33_hiphop_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/34_rock_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/35_rock_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/36_rock_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/37_rock_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/38_rock_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/4_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/40_hiphop_110_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/41_hiphop_110_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/42_rock_110_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/43_rock_110_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/47_rock_110_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/48_rock_110_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/5_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/6_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/7_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/8_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer3/session2/9_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer4/session1/1_rock_87_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer4/session1/2_jazz_158_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer4/session1/3_jazz-klezmer_152_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer4/session1/4_latin-brazilian_92_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer4/session1/5_latin-brazilian_184_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer4/session1/6_blues-shuffle_134_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer4/session1/7_blues-shuffle_134_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer4/session1/8_blues-shuffle_112_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer4/session1/9_latin-merengue_158_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/eval_session/1_funk-groove1_138_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/eval_session/10_soul-groove10_102_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/eval_session/2_funk-groove2_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/eval_session/3_soul-groove3_86_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/eval_session/4_soul-groove4_80_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/eval_session/5_funk-groove5_84_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/eval_session/6_hiphop-groove6_87_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/eval_session/7_pop-groove7_138_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/eval_session/8_rock-groove8_65_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/eval_session/9_soul-groove9_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/1_latin-brazilian-bossa_127_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/10_latin-brazilian-sambareggae_96_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/11_latin-brazilian-sambareggae_96_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/12_latin-brazilian-sambareggae_96_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/13_afrocuban-calypso_124_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/14_latin-brazilian-songo_112_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/15_funk_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/16_rock_136_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/17_blues-shuffle_72_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/18_afrocuban_128_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/19_middleeastern_126_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/2_latin-brazilian-bossa_127_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/20_latin-brazilian-baiao_110_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/3_latin-brazilian-samba_89_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/4_latin-brazilian-samba_89_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/5_latin-brazilian-samba_89_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/6_latin-brazilian-maracatu_96_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/7_latin-brazilian-maracatu_96_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/8_latin-venezuelan-merengue_162_beat_5-8.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session1/9_latin-dominican-merengue_130_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/1_latin-venezuelan-sangueo_101_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/10_neworleans-funk_102_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/11_soul_96_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/12_rock_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/13_rock_140_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/14_rock_140_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/15_latin-venezuelan-joropo_80_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/16_latin-ando_125_beat_3-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/17_latin-brazilian-samba_110_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/18_latin-brazilian-samba_93_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/19_latin-brazilian-ijexa_108_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/2_latin-brazilian_101_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/20_latin-brazilian-ijexa_108_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/21_latin-brazilian-ijexa_108_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/22_latin-brazilian-frevo_133_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/23_latin-brazilian-songo_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/24_latin-brazilian-songo_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/3_latin-brazilian_101_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/4_reggae_141_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/5_reggae_126_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/6_neworleans-secondline_99_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/7_neworleans-secondline_124_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer5/session2/8_neworleans-chacha_124_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ...
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer7/session3/38_hiphop_67_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer7/session3/39_rock-indie_63_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer7/session3/46_rock-indie_63_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer7/session3/47_funk_112_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer7/session3/48_funk_112_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer7/session3/49_funk_112_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer7/session3/64_funk_112_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer7/session3/65_funk_112_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer7/session3/67_neworleans-funk_93_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer7/session3/91_neworleans-funk_93_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer7/session3/92_hiphop_70_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/eval_session/1_funk-groove1_138_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/eval_session/10_soul-groove10_102_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/eval_session/2_funk-groove2_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/eval_session/3_soul-groove3_86_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/eval_session/4_soul-groove4_80_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/eval_session/5_funk-groove5_84_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/eval_session/6_hiphop-groove6_87_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/eval_session/7_pop-groove7_138_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/eval_session/8_rock-groove8_65_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/eval_session/9_soul-groove9_105_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/1_funk_95_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/10_neworleans-funk_82_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/11_neworleans-funk_82_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/12_latin_118_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/13_latin_118_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/14_hiphop_94_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/15_hiphop_94_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/16_afrobeat_90_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/17_afrobeat_90_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/18_funk_108_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/19_funk_108_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/2_funk_95_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/20_rock-shuffle_112_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/21_rock-shuffle_112_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/22_funk_115_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/23_hiphop_70_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/24_funk-latin_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/25_funk-latin_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/26_afrobeat_94_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/27_latin_122_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/28_rock_102_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/3_hiphop_90_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/4_hiphop_90_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/5_hiphop_90_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/6_funk_80_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/7_funk_80_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/8_funk_96_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer8/session1/9_funk_96_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/1_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/10_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/11_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/12_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/13_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/14_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/15_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/16_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/17_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/18_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/19_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/2_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/20_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/21_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/22_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/23_rock_120_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/24_rock_90_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/25_rock_90_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/26_rock_90_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/27_rock_90_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/28_rock_90_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/29_rock_90_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/3_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/30_rock_90_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/4_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/5_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/6_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/7_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/8_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ..\Datasets\groove\drummer9/session1/9_rock_100_beat_4-4.wav
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!

# %%
data['fitting_tags']
# Out:
# 0             [funk]
# 1               None
# 2             [funk]
# 3               None
# 4             [soul]
#             ...
# 1085    [rock, rock]
# 1086    [rock, rock]
# 1087    [rock, rock]
# 1088    [rock, rock]
# 1089    [rock, rock]
# Name: fitting_tags, Length: 426, dtype: object

# %%
data['fitting_tags'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1709, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [rock, rock]           159
# [jazz]                  45
# [funk]                  41
# [soul]                  21
# [pop]                    9
# [rock]                   8
# [beat]                   6
# [pop, pop]               4
# [fast, jazz]             3
# [rock, indie, rock]      2
# [soft, pop]              2
# [jazz, funk]             2
# [dance]                  2
# [rock, rock, folk]       1
# [blues]                  1
# [fast, funk]             1
# [slow]                   1
# [punk]                   1
# Name: fitting_tags, dtype: int64

# %%
data['fitting_tags'].notnull().sum() / len(data)
# Out:
# 0.7253521126760564

# %%
data.to_csv('musicnn_classification.csv', index=False)

# %% [markdown]
# # Tests

# %%
top_tags('G:\Musik\Aphex Twin\Windowlicker\\01 Windowlicker.wma', model='MTT_musicnn', topN=15, print_tags=False)
# Out:
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow)..
# d:\Programmierung\anaconda3\envs\musicnn\lib\site-packages\librosa\core\audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# done!
# ['techno',
#  'electronic',
#  'beat',
#  'synth',
#  'fast',
#  'female',
#  'loud',
#  'drums',
#  'woman',
#  'female vocal',
#  'pop',
#  'female voice',
#  'vocal',
#  'dance',
#  'beats']

# %%
top_tags('G:\Musik\Arctic Monkeys\Humbug\\09 Pretty Visitors.mp3', model='MTT_musicnn', topN=15, print_tags=False)
# Out:
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ['rock',
#  'male',
#  'male vocal',
#  'guitar',
#  'loud',
#  'drums',
#  'vocal',
#  'vocals',
#  'pop',
#  'man',
#  'fast',
#  'singing',
#  'male voice',
#  'slow',
#  'metal']

# %%
top_tags('G:\Musik\Sade\\Sade - Tar Baby.mp3', model='MTT_musicnn', topN=15, print_tags=False)
# Out:
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ['female',
#  'guitar',
#  'vocal',
#  'woman',
#  'drums',
#  'singing',
#  'female vocal',
#  'pop',
#  'vocals',
#  'slow',
#  'indian',
#  'female voice',
#  'voice',
#  'strings',
#  'rock']

# %%
top_tags('G:\Musik\Shakti\Shakti with John McLaughlin\\Joy.wma', model='MTT_musicnn', topN=15, print_tags=False)
# Out:
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ['fast',
#  'indian',
#  'drums',
#  'guitar',
#  'strings',
#  'sitar',
#  'classical',
#  'no vocals',
#  'techno',
#  'no vocal',
#  'beat',
#  'violin',
#  'loud',
#  'no voice',
#  'harpsichord']

# %%
top_tags('G:\Musik\Beginner\\Absolute Beginner - Füchse.mp3', model='MSD_musicnn', topN=15, print_tags=False)
# Out:
# Computing spectrogram (w/ librosa) and tags (w/ tensorflow).. done!
# ['Hip-Hop',
#  'electronic',
#  'rock',
#  'indie',
#  'pop',
#  'soul',
#  'alternative',
#  'rnb',
#  'chillout',
#  'funk',
#  '00s',
#  'dance',
#  'jazz',
#  'indie rock',
#  'chill']
